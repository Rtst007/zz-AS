# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import argparse
import numpy as np
import matplotlib.pyplot as plt

# import datetime
# import scipy.io as sio

from func_model import My_RNN_model
from func_utils import train_model, validate_model, test_model

# %%
# Check GPU or CPU for training.
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print('Using device:', device)
# Out:
# Using device: cuda:1

# %%
'设置随机种子'
# seed = 116
# torch.manual_seed(seed)
# torch.cuda.manual_seed(seed) 
# torch.cuda.manual_seed_all(seed)
# torch.backends.cudnn.deterministic = True
# torch.backends.cudnn.benchmark = False
# np.random.seed(seed)

'Learning Parameters'
# initial_run = 0    # 0: Continue training; 1: Starts from the scratch
# max_epochs = 10000    # Num of epochs
# learning_rate = 0.0001  # Learning rate

max_epochs = 40         # Num of epochs
learning_rate = 0.0001  # Learning rate

'System Information'
M_antanna_num = 8      # Number of BS's antennas, 对应论文中的 Mr 基站的天线个数
N_grid_point_num = 128  # Number of posterior intervals inputed to DNN
# N_grid_point_num = 16  # Number of posterior intervals inputed to DNN
S = np.log2(N_grid_point_num)   # 波束模式的分级 数
tau = int(2*S)  # Pilot length

'Channel Information'
# phi_min = -60*(np.pi/180)   # Lower-bound of AoAs
phi_min = 0*(np.pi/180)   # Lower-bound of AoAs
phi_max = 60*(np.pi/180)    # Upper-bound of AoAs
num_SNR = 8         # Number of considered SNRs
low_SNR_idx = 0     # Index of Lowest SNR for training
high_SNR_idx = 8    # Index of highest SNR for training + 1
idx_SNR_val = 7     # Index of SNR for validation (saving parameters)

snrdBvec = np.linspace(start=-10, stop=25, num=num_SNR)  # Set of SNRs
Pvec = 10 ** (snrdBvec / 10)        # Set of considered TX powers

'Learning Parameters'
batch_per_epoch = 10    # Number of mini batches per epoch

batch_size_order = 8    # Mini_batch_size = batch_size_order*delta_inv
batch_size_train = batch_size_order * N_grid_point_num
val_size_order = 782  # Validation_set_size = val_size_order*delta_inv
batch_size_val = val_size_order * N_grid_point_num
scale_factor = 1  # Scaling the number of tests
test_size_order = 782  # Test_set_size = test_size_order*delta_inv*scale_factor
batch_size_test = test_size_order * N_grid_point_num

hidden_size = 512

# %%
argparser = argparse.ArgumentParser(description = 'Active Learning of Sensing Vector')
argparser.add_argument('--max_epochs', type =int, help='Num of Epoches', default = max_epochs)
argparser.add_argument('--learning_rate', type = float, help='Learning Rate', default = learning_rate)
argparser.add_argument('--M_antenna_num', type = int, help='Number of Antennas', default = M_antanna_num)
argparser.add_argument('--N_grid_point_num', type = int, help='Number of Angle Intervals', default = N_grid_point_num)
argparser.add_argument('--S', type = int, help='Number of Tiers (log2(N_grid_point_num))', default = S)
argparser.add_argument('--tau', type = int, help='Number of LSTM cells (2*S)', default = tau)
argparser.add_argument('--phi_min', type = float, help='Lower-limit of AoAs', default = phi_min)
argparser.add_argument('--phi_max', type = float, help='Upper-limit of AoAs', default = phi_max)
argparser.add_argument('--num_SNR', type = int, help='Number of Considered SNR Levels', default = num_SNR)
argparser.add_argument('--low_SNR_idx', type = int, help='Index of Lowest SNR for training', default = low_SNR_idx)
argparser.add_argument('--high_SNR_idx', type = int, help='Index of highest SNR for training + 1', default = high_SNR_idx)
argparser.add_argument('--idx_SNR_val', type = float, help='Index of SNR for validation', default = idx_SNR_val)
argparser.add_argument('--snrdBvec', type = float, help='Set of SNRs', default = snrdBvec)
argparser.add_argument('--Pvec', type = float, help='powers', default = Pvec)
argparser.add_argument('--batch_per_epoch', type = int, help='Number of mini batches per epoch', default = batch_per_epoch)
argparser.add_argument('--batch_size_order', type = int, help='Mini_batch_size = batch_size_order*delta_inv', default = batch_size_order)
argparser.add_argument('--val_size_order', type = int, help='Validation_set_size = val_size_order*delta_inv', default = val_size_order)
argparser.add_argument('--test_size_order', type = int, help='Test_set_size = test_size_order*delta_inv*scale_factor', default = test_size_order)
argparser.add_argument('--batch_size_train', type = int, help='Number of mini batches per epoch', default = batch_size_train)
argparser.add_argument('--batch_size_val', type = int, help='Number of mini batches per epoch', default = batch_size_val)
argparser.add_argument('--batch_size_test', type = int, help='Number of mini batches per epoch', default = batch_size_test)

argparser.add_argument('--hidden_size', type = int, help='Hidden Node Size', default = hidden_size)

args, _ = argparser.parse_known_args()
print(args)
# Out:
# Namespace(max_epochs=40, learning_rate=0.0001, M_antenna_num=8, N_grid_point_num=128, S=7.0, tau=14, phi_min=0.0, phi_max=1.0471975511965976, num_SNR=8, low_SNR_idx=0, high_SNR_idx=8, idx_SNR_val=7, snrdBvec=array([-10.,  -5.,   0.,   5.,  10.,  15.,  20.,  25.]), Pvec=array([1.00000000e-01, 3.16227766e-01, 1.00000000e+00, 3.16227766e+00,
#        1.00000000e+01, 3.16227766e+01, 1.00000000e+02, 3.16227766e+02]), batch_per_epoch=10, batch_size_order=8, val_size_order=782, test_size_order=782, batch_size_train=1024, batch_size_val=100096, batch_size_test=100096, hidden_size=512)

# %%
model = My_RNN_model(args).to(device)
criterion = nn.MSELoss(reduction='mean')
optimizer = optim.Adam(params=model.parameters(), lr=args.learning_rate)

resume = 1
PATH = './checkpoints/' + model.name() + '_weights.pth'
if resume == 1:
    model.load_state_dict( torch.load(PATH, map_location=device) )
# Out:
# /home/xiangming/miniconda3/envs/pytorch-1/lib/python3.9/site-packages/torch/cuda/__init__.py:611: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")

# %%
best_val_loss = validate_model(model=model, criterion=criterion, args=args)
# start training
for epoch in range(max_epochs):

    train_loss = train_model(model=model, criterion=criterion, optimizer=optimizer, args=args)
    validate_loss = validate_model(model=model, criterion=criterion, args=args)

    print('\n'f"Epoch {epoch}-----------------------------------------------")
    print('epoch:', epoch, ' train_loss:%2.9f' % train_loss, ' validate_loss:%2.9f' % validate_loss, ' best_val_loss:%2.9f' % best_val_loss)

    if validate_loss < best_val_loss:
        best_val_loss = validate_loss        
        torch.save(model.state_dict(), PATH)
# Out:
# Epoch 0-----------------------------------------------
# epoch: 0  train_loss:0.004577343  validate_loss:0.003172816  best_val_loss:0.002493114
#
# Epoch 1-----------------------------------------------
# epoch: 1  train_loss:0.003349023  validate_loss:0.003809185  best_val_loss:0.002493114
#
# Epoch 2-----------------------------------------------
# epoch: 2  train_loss:0.007621828  validate_loss:0.001974160  best_val_loss:0.002493114
#
# Epoch 3-----------------------------------------------
# epoch: 3  train_loss:0.004597444  validate_loss:0.001217737  best_val_loss:0.001974160
#
# Epoch 4-----------------------------------------------
# epoch: 4  train_loss:0.009009088  validate_loss:0.003317143  best_val_loss:0.001217737
#
# Epoch 5-----------------------------------------------
# epoch: 5  train_loss:0.008991872  validate_loss:0.010978051  best_val_loss:0.001217737
#
# Epoch 6-----------------------------------------------
# epoch: 6  train_loss:0.006528766  validate_loss:0.001501212  best_val_loss:0.001217737
#
# Epoch 7-----------------------------------------------
# epoch: 7  train_loss:0.005866181  validate_loss:0.002713795  best_val_loss:0.001217737
#
# Epoch 8-----------------------------------------------
# epoch: 8  train_loss:0.004655487  validate_loss:0.001219627  best_val_loss:0.001217737
#
# Epoch 9-----------------------------------------------
# epoch: 9  train_loss:0.004408089  validate_loss:0.001371889  best_val_loss:0.001217737
#
# Epoch 10-----------------------------------------------
# epoch: 10  train_loss:0.005316906  validate_loss:0.001057934  best_val_loss:0.001217737
#
# Epoch 11-----------------------------------------------
# epoch: 11  train_loss:0.002432901  validate_loss:0.000825964  best_val_loss:0.001057934
#
# Epoch 12-----------------------------------------------
# epoch: 12  train_loss:0.004480525  validate_loss:0.001158665  best_val_loss:0.000825964
#
# Epoch 13-----------------------------------------------
# epoch: 13  train_loss:0.001900017  validate_loss:0.000993108  best_val_loss:0.000825964
#
# Epoch 14-----------------------------------------------
# epoch: 14  train_loss:0.002764972  validate_loss:0.000667013  best_val_loss:0.000825964
#
# Epoch 15-----------------------------------------------
# epoch: 15  train_loss:0.001721357  validate_loss:0.000736332  best_val_loss:0.000667013
#
# Epoch 16-----------------------------------------------
# epoch: 16  train_loss:0.002305328  validate_loss:0.000731293  best_val_loss:0.000667013
#
# Epoch 17-----------------------------------------------
# epoch: 17  train_loss:0.004168490  validate_loss:0.000613907  best_val_loss:0.000667013
#
# Epoch 18-----------------------------------------------
# epoch: 18  train_loss:0.002572567  validate_loss:0.000609325  best_val_loss:0.000613907
#
# Epoch 19-----------------------------------------------
# epoch: 19  train_loss:0.004640645  validate_loss:0.000678048  best_val_loss:0.000609325
#
# Epoch 20-----------------------------------------------
# epoch: 20  train_loss:0.001094512  validate_loss:0.000790622  best_val_loss:0.000609325
#
# Epoch 21-----------------------------------------------
# epoch: 21  train_loss:0.001477503  validate_loss:0.000622823  best_val_loss:0.000609325
#
# Epoch 22-----------------------------------------------
# epoch: 22  train_loss:0.002898806  validate_loss:0.000531103  best_val_loss:0.000609325
#
# Epoch 23-----------------------------------------------
# epoch: 23  train_loss:0.003588775  validate_loss:0.000520250  best_val_loss:0.000531103
#
# Epoch 24-----------------------------------------------
# epoch: 24  train_loss:0.002881684  validate_loss:0.000547269  best_val_loss:0.000520250
#
# Epoch 25-----------------------------------------------
# epoch: 25  train_loss:0.001978942  validate_loss:0.000658812  best_val_loss:0.000520250
#
# Epoch 26-----------------------------------------------
# epoch: 26  train_loss:0.002626792  validate_loss:0.000582893  best_val_loss:0.000520250
#
# Epoch 27-----------------------------------------------
# epoch: 27  train_loss:0.003369639  validate_loss:0.000718227  best_val_loss:0.000520250
#
# Epoch 28-----------------------------------------------
# epoch: 28  train_loss:0.003880525  validate_loss:0.000531022  best_val_loss:0.000520250
#
# Epoch 29-----------------------------------------------
# epoch: 29  train_loss:0.001280649  validate_loss:0.000514474  best_val_loss:0.000520250
#
# Epoch 30-----------------------------------------------
# epoch: 30  train_loss:0.005490338  validate_loss:0.000515190  best_val_loss:0.000514474
#
# Epoch 31-----------------------------------------------
# epoch: 31  train_loss:0.000513953  validate_loss:0.000532063  best_val_loss:0.000514474
#
# Epoch 32-----------------------------------------------
# epoch: 32  train_loss:0.003988254  validate_loss:0.000529713  best_val_loss:0.000514474
#
# Epoch 33-----------------------------------------------
# epoch: 33  train_loss:0.003601853  validate_loss:0.000504735  best_val_loss:0.000514474
#
# Epoch 34-----------------------------------------------
# epoch: 34  train_loss:0.001047023  validate_loss:0.000470908  best_val_loss:0.000504735
#
# Epoch 35-----------------------------------------------
# epoch: 35  train_loss:0.003198738  validate_loss:0.000549098  best_val_loss:0.000470908
#
# Epoch 36-----------------------------------------------
# epoch: 36  train_loss:0.002471148  validate_loss:0.000503603  best_val_loss:0.000470908
#
# Epoch 37-----------------------------------------------
# epoch: 37  train_loss:0.002657357  validate_loss:0.000505731  best_val_loss:0.000470908
#
# Epoch 38-----------------------------------------------
# epoch: 38  train_loss:0.005168975  validate_loss:0.000725632  best_val_loss:0.000470908
#
# Epoch 39-----------------------------------------------
# epoch: 39  train_loss:0.002231717  validate_loss:0.000783524  best_val_loss:0.000470908
#
# Epoch 40-----------------------------------------------
# epoch: 40  train_loss:0.004097514  validate_loss:0.000519833  best_val_loss:0.000470908
#
# Epoch 41-----------------------------------------------
# epoch: 41  train_loss:0.003784200  validate_loss:0.000651315  best_val_loss:0.000470908
#
# Epoch 42-----------------------------------------------
# epoch: 42  train_loss:0.001676579  validate_loss:0.000625783  best_val_loss:0.000470908
#
# Epoch 43-----------------------------------------------
# epoch: 43  train_loss:0.002057567  validate_loss:0.000447146  best_val_loss:0.000470908
#
# Epoch 44-----------------------------------------------
# epoch: 44  train_loss:0.002457960  validate_loss:0.000610907  best_val_loss:0.000447146
#
# Epoch 45-----------------------------------------------
# epoch: 45  train_loss:0.005787099  validate_loss:0.000970723  best_val_loss:0.000447146
#
# Epoch 46-----------------------------------------------
# epoch: 46  train_loss:0.001229345  validate_loss:0.000661625  best_val_loss:0.000447146
#
# Epoch 47-----------------------------------------------
# epoch: 47  train_loss:0.004416690  validate_loss:0.000544843  best_val_loss:0.000447146
#
# Epoch 48-----------------------------------------------
# epoch: 48  train_loss:0.003375692  validate_loss:0.000542229  best_val_loss:0.000447146
#
# Epoch 49-----------------------------------------------
# epoch: 49  train_loss:0.001972761  validate_loss:0.000510019  best_val_loss:0.000447146
#
# Epoch 50-----------------------------------------------
# epoch: 50  train_loss:0.001799276  validate_loss:0.000428043  best_val_loss:0.000447146
#
# Epoch 51-----------------------------------------------
# epoch: 51  train_loss:0.000579365  validate_loss:0.000466875  best_val_loss:0.000428043
#
# Epoch 52-----------------------------------------------
# epoch: 52  train_loss:0.007650932  validate_loss:0.000810705  best_val_loss:0.000428043
#
# Epoch 53-----------------------------------------------
# epoch: 53  train_loss:0.002648675  validate_loss:0.000602446  best_val_loss:0.000428043
#
# Epoch 54-----------------------------------------------
# epoch: 54  train_loss:0.003167061  validate_loss:0.000815392  best_val_loss:0.000428043
#
# Epoch 55-----------------------------------------------
# epoch: 55  train_loss:0.003447013  validate_loss:0.002547422  best_val_loss:0.000428043
#
# Epoch 56-----------------------------------------------
# epoch: 56  train_loss:0.002972181  validate_loss:0.010181828  best_val_loss:0.000428043
#
# Epoch 57-----------------------------------------------
# epoch: 57  train_loss:0.005404227  validate_loss:0.003771559  best_val_loss:0.000428043
#
# Epoch 58-----------------------------------------------
# epoch: 58  train_loss:0.004195302  validate_loss:0.001231782  best_val_loss:0.000428043
#
# Epoch 59-----------------------------------------------
# epoch: 59  train_loss:0.005241302  validate_loss:0.000604434  best_val_loss:0.000428043
#
# Epoch 60-----------------------------------------------
# epoch: 60  train_loss:0.005343457  validate_loss:0.001808688  best_val_loss:0.000428043
#
# Epoch 61-----------------------------------------------
# epoch: 61  train_loss:0.003552111  validate_loss:0.003916153  best_val_loss:0.000428043
#
# Epoch 62-----------------------------------------------
# epoch: 62  train_loss:0.003743587  validate_loss:0.000522793  best_val_loss:0.000428043
#
# Epoch 63-----------------------------------------------
# epoch: 63  train_loss:0.007977593  validate_loss:0.001732463  best_val_loss:0.000428043
#
# Epoch 64-----------------------------------------------
# epoch: 64  train_loss:0.002000184  validate_loss:0.000772275  best_val_loss:0.000428043
#
# Epoch 65-----------------------------------------------
# epoch: 65  train_loss:0.002355894  validate_loss:0.000645466  best_val_loss:0.000428043
#
# Epoch 66-----------------------------------------------
# epoch: 66  train_loss:0.003754551  validate_loss:0.000544741  best_val_loss:0.000428043
#
# Epoch 67-----------------------------------------------
# epoch: 67  train_loss:0.004787838  validate_loss:0.002202779  best_val_loss:0.000428043
#
# Epoch 68-----------------------------------------------
# epoch: 68  train_loss:0.002922597  validate_loss:0.000521840  best_val_loss:0.000428043
#
# Epoch 69-----------------------------------------------
# epoch: 69  train_loss:0.000617402  validate_loss:0.000451006  best_val_loss:0.000428043
#
# Epoch 70-----------------------------------------------
# epoch: 70  train_loss:0.000791870  validate_loss:0.002338905  best_val_loss:0.000428043
#
# Epoch 71-----------------------------------------------
# epoch: 71  train_loss:0.001997988  validate_loss:0.000400979  best_val_loss:0.000428043
#
# Epoch 72-----------------------------------------------
# epoch: 72  train_loss:0.000951952  validate_loss:0.000426090  best_val_loss:0.000400979
#
# Epoch 73-----------------------------------------------
# epoch: 73  train_loss:0.002713278  validate_loss:0.000388773  best_val_loss:0.000400979
#
# Epoch 74-----------------------------------------------
# epoch: 74  train_loss:0.002175460  validate_loss:0.000386761  best_val_loss:0.000388773
#
# Epoch 75-----------------------------------------------
# epoch: 75  train_loss:0.003330674  validate_loss:0.000373790  best_val_loss:0.000386761
#
# Epoch 76-----------------------------------------------
# epoch: 76  train_loss:0.001974437  validate_loss:0.000499154  best_val_loss:0.000373790
#
# Epoch 77-----------------------------------------------
# epoch: 77  train_loss:0.004497889  validate_loss:0.000420483  best_val_loss:0.000373790
#
# Epoch 78-----------------------------------------------
# epoch: 78  train_loss:0.003684546  validate_loss:0.000370040  best_val_loss:0.000373790
#
# Epoch 79-----------------------------------------------
# epoch: 79  train_loss:0.004411123  validate_loss:0.000419691  best_val_loss:0.000370040
#
# Epoch 80-----------------------------------------------
# epoch: 80  train_loss:0.004114736  validate_loss:0.001065499  best_val_loss:0.000370040
#
# Epoch 81-----------------------------------------------
# epoch: 81  train_loss:0.005464277  validate_loss:0.000689440  best_val_loss:0.000370040
#
# Epoch 82-----------------------------------------------
# epoch: 82  train_loss:0.000682364  validate_loss:0.000416587  best_val_loss:0.000370040
#
# Epoch 83-----------------------------------------------
# epoch: 83  train_loss:0.005198366  validate_loss:0.000494899  best_val_loss:0.000370040
#
# Epoch 84-----------------------------------------------
# epoch: 84  train_loss:0.002414610  validate_loss:0.000662402  best_val_loss:0.000370040
#
# Epoch 85-----------------------------------------------
# epoch: 85  train_loss:0.004436761  validate_loss:0.000431668  best_val_loss:0.000370040
#
# Epoch 86-----------------------------------------------
# epoch: 86  train_loss:0.002508310  validate_loss:0.000586180  best_val_loss:0.000370040
#
# Epoch 87-----------------------------------------------
# epoch: 87  train_loss:0.002189772  validate_loss:0.000414100  best_val_loss:0.000370040
#
# Epoch 88-----------------------------------------------
# epoch: 88  train_loss:0.001181869  validate_loss:0.000630828  best_val_loss:0.000370040
#
# Epoch 89-----------------------------------------------
# epoch: 89  train_loss:0.002493748  validate_loss:0.000543405  best_val_loss:0.000370040
#
# Epoch 90-----------------------------------------------
# epoch: 90  train_loss:0.001237813  validate_loss:0.000626324  best_val_loss:0.000370040
#
# Epoch 91-----------------------------------------------
# epoch: 91  train_loss:0.005478941  validate_loss:0.000385499  best_val_loss:0.000370040
#
# Epoch 92-----------------------------------------------
# epoch: 92  train_loss:0.000518091  validate_loss:0.000384734  best_val_loss:0.000370040
#
# Epoch 93-----------------------------------------------
# epoch: 93  train_loss:0.001676462  validate_loss:0.000615099  best_val_loss:0.000370040
#
# Epoch 94-----------------------------------------------
# epoch: 94  train_loss:0.002442816  validate_loss:0.001099816  best_val_loss:0.000370040
#
# Epoch 95-----------------------------------------------
# epoch: 95  train_loss:0.002757733  validate_loss:0.001301090  best_val_loss:0.000370040
#
# Epoch 96-----------------------------------------------
# epoch: 96  train_loss:0.003979770  validate_loss:0.000834261  best_val_loss:0.000370040
#
# Epoch 97-----------------------------------------------
# epoch: 97  train_loss:0.001846571  validate_loss:0.000722158  best_val_loss:0.000370040
#
# Epoch 98-----------------------------------------------
# epoch: 98  train_loss:0.003362337  validate_loss:0.000640247  best_val_loss:0.000370040
#
# Epoch 99-----------------------------------------------
# epoch: 99  train_loss:0.003879206  validate_loss:0.000434663  best_val_loss:0.000370040

# %%
# start testing
snrdBvec, performance = test_model(model=model, criterion=criterion, args=args)
print('snrdBvec:', snrdBvec)
print('performance:', performance)
print("Done!-----------------------------------------------------------------\n")

np.save('snrdBvec.npy', snrdBvec)
np.save('performance.npy', performance)


# Create a figure and axis
fig, ax = plt.subplots()
# Plot data
ax.semilogy(snrdBvec, performance, label='MSE vs SNR', marker='o')
# Set labels and title
ax.set_xlabel('SNR (dB)')
ax.set_ylabel('MSE')
ax.set_title('MSE vs SNR')
# Display legend
ax.legend()
# Show the plot
plt.show()
# Out:
# snrdBvec: [-10.  -5.   0.   5.  10.  15.  20.  25.]
# performance: [0.01898038 0.00530444 0.001376   0.00044154 0.00024485 0.00019511
#  0.00017716 0.00016508]
# Done!-----------------------------------------------------------------

# %%
data_snrdBvec = np.load('snrdBvec.npy')
data_performance_active = np.load('performance.npy')
data_performance_fixed = np.load('performance_fixed.npy')

print(data_snrdBvec)
print(data_performance_active)
print(data_performance_fixed)

angle_degree_active = np.sqrt(data_performance_active)*180/np.pi
angle_degree_fixed = np.sqrt(data_performance_fixed)*180/np.pi

 # Create a figure and axis
fig, ax = plt.subplots()
# Plot data
ax.semilogy(snrdBvec, angle_degree_active, label='Active sensing beamforming', marker='o')
ax.semilogy(snrdBvec, angle_degree_fixed, label='Fixed beamforming', marker='*')
# Set labels and title
ax.set_xlabel('SNR (dB)')
ax.set_ylabel('angular deviation (degree)')
ax.set_title('angle degree vs SNR')
# Display legend
ax.legend()
# Show the plot
plt.show()
# Out:
# [-10.  -5.   0.   5.  10.  15.  20.  25.]
# [0.01898038 0.00530444 0.001376   0.00044154 0.00024485 0.00019511
#  0.00017716 0.00016508]
# [0.02799631 0.01219727 0.00417313 0.00158536 0.00089289 0.00065337
#  0.00058319 0.00057039]

# %%
print(np.sqrt(1/(99.0+1.0)))
# Out:
# 0.1
