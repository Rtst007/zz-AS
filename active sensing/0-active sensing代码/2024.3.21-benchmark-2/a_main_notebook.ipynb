# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import argparse
import numpy as np
import matplotlib.pyplot as plt

# import datetime
# import scipy.io as sio

from func_model import My_RNN_model
from func_utils import train_model, validate_model, test_model

# %%
# Check GPU or CPU for training.
device = torch.device("cuda:2" if torch.cuda.is_available() else "cpu")
print('Using device:', device)
# Out:
# Using device: cuda:2

# %%
'设置随机种子'
# seed = 116
# torch.manual_seed(seed)
# torch.cuda.manual_seed(seed)
# torch.cuda.manual_seed_all(seed)
# torch.backends.cudnn.deterministic = True
# torch.backends.cudnn.benchmark = False
# np.random.seed(seed)

'Learning Parameters'
# initial_run = 0    # 0: Continue training; 1: Starts from the scratch
# max_epochs = 10000    # Num of epochs
# learning_rate = 0.0001  # Learning rate

max_epochs = 40         # Num of epochs
learning_rate = 0.0001  # Learning rate

'System Information'
M_antanna_num = 8      # Number of BS's antennas, 对应论文中的 Mr 基站的天线个数
N_grid_point_num = 128  # Number of posterior intervals inputed to DNN
# N_grid_point_num = 16  # Number of posterior intervals inputed to DNN
S = np.log2(N_grid_point_num)   # 波束模式的分级 数
tau = int(2*S)  # Pilot length

'Channel Information'
# phi_min = -60*(np.pi/180)   # Lower-bound of AoAs
phi_min = 0*(np.pi/180)   # Lower-bound of AoAs
phi_max = 60*(np.pi/180)    # Upper-bound of AoAs
num_SNR = 8         # Number of considered SNRs
low_SNR_idx = 0     # Index of Lowest SNR for training
high_SNR_idx = 8    # Index of highest SNR for training + 1
idx_SNR_val = 7     # Index of SNR for validation (saving parameters)

snrdBvec = np.linspace(start=-10, stop=25, num=num_SNR)  # Set of SNRs
Pvec = 10 ** (snrdBvec / 10)        # Set of considered TX powers

'Learning Parameters'
batch_per_epoch = 10    # Number of mini batches per epoch

batch_size_order = 8    # Mini_batch_size = batch_size_order*delta_inv
batch_size_train = batch_size_order * N_grid_point_num
val_size_order = 782  # Validation_set_size = val_size_order*delta_inv
batch_size_val = val_size_order * N_grid_point_num
scale_factor = 1  # Scaling the number of tests
test_size_order = 782  # Test_set_size = test_size_order*delta_inv*scale_factor
batch_size_test = test_size_order * N_grid_point_num

hidden_size = 512

# %%
argparser = argparse.ArgumentParser(description = 'Active Learning of Sensing Vector')
argparser.add_argument('--max_epochs', type =int, help='Num of Epoches', default = max_epochs)
argparser.add_argument('--learning_rate', type = float, help='Learning Rate', default = learning_rate)
argparser.add_argument('--M_antenna_num', type = int, help='Number of Antennas', default = M_antanna_num)
argparser.add_argument('--N_grid_point_num', type = int, help='Number of Angle Intervals', default = N_grid_point_num)
argparser.add_argument('--S', type = int, help='Number of Tiers (log2(N_grid_point_num))', default = S)
argparser.add_argument('--tau', type = int, help='Number of LSTM cells (2*S)', default = tau)
argparser.add_argument('--phi_min', type = float, help='Lower-limit of AoAs', default = phi_min)
argparser.add_argument('--phi_max', type = float, help='Upper-limit of AoAs', default = phi_max)
argparser.add_argument('--num_SNR', type = int, help='Number of Considered SNR Levels', default = num_SNR)
argparser.add_argument('--low_SNR_idx', type = int, help='Index of Lowest SNR for training', default = low_SNR_idx)
argparser.add_argument('--high_SNR_idx', type = int, help='Index of highest SNR for training + 1', default = high_SNR_idx)
argparser.add_argument('--idx_SNR_val', type = float, help='Index of SNR for validation', default = idx_SNR_val)
argparser.add_argument('--snrdBvec', type = float, help='Set of SNRs', default = snrdBvec)
argparser.add_argument('--Pvec', type = float, help='powers', default = Pvec)
argparser.add_argument('--batch_per_epoch', type = int, help='Number of mini batches per epoch', default = batch_per_epoch)
argparser.add_argument('--batch_size_order', type = int, help='Mini_batch_size = batch_size_order*delta_inv', default = batch_size_order)
argparser.add_argument('--val_size_order', type = int, help='Validation_set_size = val_size_order*delta_inv', default = val_size_order)
argparser.add_argument('--test_size_order', type = int, help='Test_set_size = test_size_order*delta_inv*scale_factor', default = test_size_order)
argparser.add_argument('--batch_size_train', type = int, help='Number of mini batches per epoch', default = batch_size_train)
argparser.add_argument('--batch_size_val', type = int, help='Number of mini batches per epoch', default = batch_size_val)
argparser.add_argument('--batch_size_test', type = int, help='Number of mini batches per epoch', default = batch_size_test)

argparser.add_argument('--hidden_size', type = int, help='Hidden Node Size', default = hidden_size)

args, _ = argparser.parse_known_args()
print(args)
# Out:
# Namespace(max_epochs=40, learning_rate=0.0001, M_antenna_num=8, N_grid_point_num=128, S=7.0, tau=14, phi_min=0.0, phi_max=1.0471975511965976, num_SNR=8, low_SNR_idx=0, high_SNR_idx=8, idx_SNR_val=7, snrdBvec=array([-10.,  -5.,   0.,   5.,  10.,  15.,  20.,  25.]), Pvec=array([1.00000000e-01, 3.16227766e-01, 1.00000000e+00, 3.16227766e+00,
#        1.00000000e+01, 3.16227766e+01, 1.00000000e+02, 3.16227766e+02]), batch_per_epoch=10, batch_size_order=8, val_size_order=782, test_size_order=782, batch_size_train=1024, batch_size_val=100096, batch_size_test=100096, hidden_size=512)

# %%
model = My_RNN_model(args).to(device)
criterion = nn.MSELoss(reduction='mean')
optimizer = optim.Adam(params=model.parameters(), lr=args.learning_rate)

resume = 1
PATH = './checkpoints/' + model.name() + '_weights.pth'
if resume == 1:
    model.load_state_dict( torch.load(PATH, map_location=device) )
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 model = My_RNN_model(args).to(device)
#       2 criterion = nn.MSELoss(reduction='mean')
#       3 optimizer = optim.Adam(params=model.parameters(), lr=args.learning_rate)
#
# File ~/miniconda3/envs/pytorch-1/lib/python3.9/site-packages/torch/nn/modules/module.py:1160, in Module.to(self, *args, **kwargs)
#    1156         return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None,
#    1157                     non_blocking, memory_format=convert_to_format)
#    1158     return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None, non_blocking)
# -> 1160 return self._apply(convert)
#
# File ~/miniconda3/envs/pytorch-1/lib/python3.9/site-packages/torch/nn/modules/module.py:810, in Module._apply(self, fn, recurse)
#     808 if recurse:
#     809     for module in self.children():
# --> 810         module._apply(fn)
#     812 def compute_should_use_set_data(tensor, tensor_applied):
#     813     if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     814         # If the new tensor has compatible tensor type as the existing tensor,
#     815         # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     820         # global flag to let the user control whether they want the future
#     821         # behavior of overwriting the existing tensor or not.
#
# File ~/miniconda3/envs/pytorch-1/lib/python3.9/site-packages/torch/nn/modules/module.py:810, in Module._apply(self, fn, recurse)
#     808 if recurse:
#     809     for module in self.children():
# --> 810         module._apply(fn)
#     812 def compute_should_use_set_data(tensor, tensor_applied):
#     813     if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     814         # If the new tensor has compatible tensor type as the existing tensor,
#     815         # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     820         # global flag to let the user control whether they want the future
#     821         # behavior of overwriting the existing tensor or not.
#
# File ~/miniconda3/envs/pytorch-1/lib/python3.9/site-packages/torch/nn/modules/module.py:833, in Module._apply(self, fn, recurse)
#     829 # Tensors stored in modules are graph leaves, and we don't want to
#     830 # track autograd history of `param_applied`, so we have to use
#     831 # `with torch.no_grad():`
#     832 with torch.no_grad():
# --> 833     param_applied = fn(param)
#     834 should_use_set_data = compute_should_use_set_data(param, param_applied)
#     835 if should_use_set_data:
#
# File ~/miniconda3/envs/pytorch-1/lib/python3.9/site-packages/torch/nn/modules/module.py:1158, in Module.to.<locals>.convert(t)
#    1155 if convert_to_format is not None and t.dim() in (4, 5):
#    1156     return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None,
#    1157                 non_blocking, memory_format=convert_to_format)
# -> 1158 return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None, non_blocking)
#
# RuntimeError: CUDA error: invalid device ordinal
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.

# %%
best_val_loss = validate_model(model=model, criterion=criterion, args=args)
# start training
for epoch in range(max_epochs):

    train_loss = train_model(model=model, criterion=criterion, optimizer=optimizer, args=args)
    validate_loss = validate_model(model=model, criterion=criterion, args=args)

    print('\n'f"Epoch {epoch}-----------------------------------------------")
    print('epoch:', epoch, ' train_loss:%2.9f' % train_loss, ' validate_loss:%2.9f' % validate_loss, ' best_val_loss:%2.9f' % best_val_loss)

    if validate_loss < best_val_loss:
        best_val_loss = validate_loss        
        torch.save(model.state_dict(), PATH)
# Out:
# Epoch 0-----------------------------------------------
# epoch: 0  train_loss:0.005987551  validate_loss:0.001992064  best_val_loss:0.002081338
#
# Epoch 1-----------------------------------------------
# epoch: 1  train_loss:0.006437812  validate_loss:0.002174413  best_val_loss:0.001992064
#
# Epoch 2-----------------------------------------------
# epoch: 2  train_loss:0.005933725  validate_loss:0.001921518  best_val_loss:0.001992064
#
# Epoch 3-----------------------------------------------
# epoch: 3  train_loss:0.005263560  validate_loss:0.001876930  best_val_loss:0.001921518
#
# Epoch 4-----------------------------------------------
# epoch: 4  train_loss:0.010721884  validate_loss:0.001853041  best_val_loss:0.001876930
#
# Epoch 5-----------------------------------------------
# epoch: 5  train_loss:0.012075251  validate_loss:0.001943049  best_val_loss:0.001853041
#
# Epoch 6-----------------------------------------------
# epoch: 6  train_loss:0.003634983  validate_loss:0.002033512  best_val_loss:0.001853041
#
# Epoch 7-----------------------------------------------
# epoch: 7  train_loss:0.006739561  validate_loss:0.001902221  best_val_loss:0.001853041
#
# Epoch 8-----------------------------------------------
# epoch: 8  train_loss:0.009073608  validate_loss:0.001805402  best_val_loss:0.001853041
#
# Epoch 9-----------------------------------------------
# epoch: 9  train_loss:0.005617477  validate_loss:0.001714792  best_val_loss:0.001805402
#
# Epoch 10-----------------------------------------------
# epoch: 10  train_loss:0.008950898  validate_loss:0.001673493  best_val_loss:0.001714792
#
# Epoch 11-----------------------------------------------
# epoch: 11  train_loss:0.007938690  validate_loss:0.001980650  best_val_loss:0.001673493
#
# Epoch 12-----------------------------------------------
# epoch: 12  train_loss:0.009721339  validate_loss:0.001670459  best_val_loss:0.001673493
#
# Epoch 13-----------------------------------------------
# epoch: 13  train_loss:0.008658627  validate_loss:0.001793383  best_val_loss:0.001670459
#
# Epoch 14-----------------------------------------------
# epoch: 14  train_loss:0.009761421  validate_loss:0.001897996  best_val_loss:0.001670459
#
# Epoch 15-----------------------------------------------
# epoch: 15  train_loss:0.006154851  validate_loss:0.002354329  best_val_loss:0.001670459
#
# Epoch 16-----------------------------------------------
# epoch: 16  train_loss:0.006718304  validate_loss:0.001676217  best_val_loss:0.001670459
#
# Epoch 17-----------------------------------------------
# epoch: 17  train_loss:0.005698550  validate_loss:0.001827201  best_val_loss:0.001670459
#
# Epoch 18-----------------------------------------------
# epoch: 18  train_loss:0.005755301  validate_loss:0.001855107  best_val_loss:0.001670459
#
# Epoch 19-----------------------------------------------
# epoch: 19  train_loss:0.005169201  validate_loss:0.001793092  best_val_loss:0.001670459
#
# Epoch 20-----------------------------------------------
# epoch: 20  train_loss:0.014305402  validate_loss:0.001625276  best_val_loss:0.001670459
#
# Epoch 21-----------------------------------------------
# epoch: 21  train_loss:0.014189654  validate_loss:0.001624402  best_val_loss:0.001625276
#
# Epoch 22-----------------------------------------------
# epoch: 22  train_loss:0.008266863  validate_loss:0.002048767  best_val_loss:0.001624402
#
# Epoch 23-----------------------------------------------
# epoch: 23  train_loss:0.006406442  validate_loss:0.001961173  best_val_loss:0.001624402
#
# Epoch 24-----------------------------------------------
# epoch: 24  train_loss:0.008611139  validate_loss:0.001578935  best_val_loss:0.001624402
#
# Epoch 25-----------------------------------------------
# epoch: 25  train_loss:0.005687211  validate_loss:0.001669573  best_val_loss:0.001578935
#
# Epoch 26-----------------------------------------------
# epoch: 26  train_loss:0.005751385  validate_loss:0.001520783  best_val_loss:0.001578935
#
# Epoch 27-----------------------------------------------
# epoch: 27  train_loss:0.006773710  validate_loss:0.001621381  best_val_loss:0.001520783
#
# Epoch 28-----------------------------------------------
# epoch: 28  train_loss:0.011535077  validate_loss:0.001821676  best_val_loss:0.001520783
#
# Epoch 29-----------------------------------------------
# epoch: 29  train_loss:0.008536414  validate_loss:0.002989324  best_val_loss:0.001520783
#
# Epoch 30-----------------------------------------------
# epoch: 30  train_loss:0.005069574  validate_loss:0.001678888  best_val_loss:0.001520783
#
# Epoch 31-----------------------------------------------
# epoch: 31  train_loss:0.005682793  validate_loss:0.001704443  best_val_loss:0.001520783
#
# Epoch 32-----------------------------------------------
# epoch: 32  train_loss:0.002057529  validate_loss:0.001871895  best_val_loss:0.001520783
#
# Epoch 33-----------------------------------------------
# epoch: 33  train_loss:0.004769078  validate_loss:0.001561693  best_val_loss:0.001520783
#
# Epoch 34-----------------------------------------------
# epoch: 34  train_loss:0.002172075  validate_loss:0.001433416  best_val_loss:0.001520783
#
# Epoch 35-----------------------------------------------
# epoch: 35  train_loss:0.006251890  validate_loss:0.001468069  best_val_loss:0.001433416
#
# Epoch 36-----------------------------------------------
# epoch: 36  train_loss:0.008828168  validate_loss:0.004998237  best_val_loss:0.001433416
#
# Epoch 37-----------------------------------------------
# epoch: 37  train_loss:0.009207473  validate_loss:0.001906012  best_val_loss:0.001433416
#
# Epoch 38-----------------------------------------------
# epoch: 38  train_loss:0.014014295  validate_loss:0.006731752  best_val_loss:0.001433416
#
# Epoch 39-----------------------------------------------
# epoch: 39  train_loss:0.010325533  validate_loss:0.009815577  best_val_loss:0.001433416
#
# Epoch 40-----------------------------------------------
# epoch: 40  train_loss:0.004781774  validate_loss:0.008125941  best_val_loss:0.001433416
#
# Epoch 41-----------------------------------------------
# epoch: 41  train_loss:0.008948037  validate_loss:0.002298312  best_val_loss:0.001433416
#
# Epoch 42-----------------------------------------------
# epoch: 42  train_loss:0.008855767  validate_loss:0.002333201  best_val_loss:0.001433416
#
# Epoch 43-----------------------------------------------
# epoch: 43  train_loss:0.014259409  validate_loss:0.004481252  best_val_loss:0.001433416
#
# Epoch 44-----------------------------------------------
# epoch: 44  train_loss:0.016423873  validate_loss:0.009788274  best_val_loss:0.001433416
#
# Epoch 45-----------------------------------------------
# epoch: 45  train_loss:0.010713228  validate_loss:0.007351767  best_val_loss:0.001433416
#
# Epoch 46-----------------------------------------------
# epoch: 46  train_loss:0.006515924  validate_loss:0.004345054  best_val_loss:0.001433416
#
# Epoch 47-----------------------------------------------
# epoch: 47  train_loss:0.006828733  validate_loss:0.002548497  best_val_loss:0.001433416
#
# Epoch 48-----------------------------------------------
# epoch: 48  train_loss:0.011145168  validate_loss:0.004594983  best_val_loss:0.001433416
#
# Epoch 49-----------------------------------------------
# epoch: 49  train_loss:0.011604622  validate_loss:0.002090071  best_val_loss:0.001433416
#
# Epoch 50-----------------------------------------------
# epoch: 50  train_loss:0.012432123  validate_loss:0.005144694  best_val_loss:0.001433416
#
# Epoch 51-----------------------------------------------
# epoch: 51  train_loss:0.007022355  validate_loss:0.002194870  best_val_loss:0.001433416
#
# Epoch 52-----------------------------------------------
# epoch: 52  train_loss:0.006694648  validate_loss:0.002969911  best_val_loss:0.001433416
#
# Epoch 53-----------------------------------------------
# epoch: 53  train_loss:0.006612925  validate_loss:0.003125334  best_val_loss:0.001433416
#
# Epoch 54-----------------------------------------------
# epoch: 54  train_loss:0.006212792  validate_loss:0.001420373  best_val_loss:0.001433416
#
# Epoch 55-----------------------------------------------
# epoch: 55  train_loss:0.009361929  validate_loss:0.001932471  best_val_loss:0.001420373
#
# Epoch 56-----------------------------------------------
# epoch: 56  train_loss:0.008937569  validate_loss:0.001290391  best_val_loss:0.001420373
#
# Epoch 57-----------------------------------------------
# epoch: 57  train_loss:0.002470847  validate_loss:0.001271513  best_val_loss:0.001290391
#
# Epoch 58-----------------------------------------------
# epoch: 58  train_loss:0.010328343  validate_loss:0.001357225  best_val_loss:0.001271513
#
# Epoch 59-----------------------------------------------
# epoch: 59  train_loss:0.004005714  validate_loss:0.001252629  best_val_loss:0.001271513
#
# Epoch 60-----------------------------------------------
# epoch: 60  train_loss:0.007256169  validate_loss:0.001268931  best_val_loss:0.001252629
#
# Epoch 61-----------------------------------------------
# epoch: 61  train_loss:0.001520320  validate_loss:0.001217561  best_val_loss:0.001252629
#
# Epoch 62-----------------------------------------------
# epoch: 62  train_loss:0.004259820  validate_loss:0.001223879  best_val_loss:0.001217561
#
# Epoch 63-----------------------------------------------
# epoch: 63  train_loss:0.003412539  validate_loss:0.001191238  best_val_loss:0.001217561
#
# Epoch 64-----------------------------------------------
# epoch: 64  train_loss:0.005622393  validate_loss:0.001214075  best_val_loss:0.001191238
#
# Epoch 65-----------------------------------------------
# epoch: 65  train_loss:0.005512657  validate_loss:0.001195261  best_val_loss:0.001191238
#
# Epoch 66-----------------------------------------------
# epoch: 66  train_loss:0.003046705  validate_loss:0.001297403  best_val_loss:0.001191238
#
# Epoch 67-----------------------------------------------
# epoch: 67  train_loss:0.009669940  validate_loss:0.001202556  best_val_loss:0.001191238
#
# Epoch 68-----------------------------------------------
# epoch: 68  train_loss:0.005563598  validate_loss:0.001178035  best_val_loss:0.001191238
#
# Epoch 69-----------------------------------------------
# epoch: 69  train_loss:0.005165122  validate_loss:0.001316466  best_val_loss:0.001178035
#
# Epoch 70-----------------------------------------------
# epoch: 70  train_loss:0.007451083  validate_loss:0.001202605  best_val_loss:0.001178035
#
# Epoch 71-----------------------------------------------
# epoch: 71  train_loss:0.004358355  validate_loss:0.001178537  best_val_loss:0.001178035
#
# Epoch 72-----------------------------------------------
# epoch: 72  train_loss:0.005419434  validate_loss:0.001238874  best_val_loss:0.001178035
#
# Epoch 73-----------------------------------------------
# epoch: 73  train_loss:0.003539582  validate_loss:0.001143914  best_val_loss:0.001178035
#
# Epoch 74-----------------------------------------------
# epoch: 74  train_loss:0.006399724  validate_loss:0.001164609  best_val_loss:0.001143914
#
# Epoch 75-----------------------------------------------
# epoch: 75  train_loss:0.006178916  validate_loss:0.001184760  best_val_loss:0.001143914
#
# Epoch 76-----------------------------------------------
# epoch: 76  train_loss:0.003701032  validate_loss:0.001151395  best_val_loss:0.001143914
#
# Epoch 77-----------------------------------------------
# epoch: 77  train_loss:0.008506769  validate_loss:0.001129869  best_val_loss:0.001143914
#
# Epoch 78-----------------------------------------------
# epoch: 78  train_loss:0.008111324  validate_loss:0.001159994  best_val_loss:0.001129869
#
# Epoch 79-----------------------------------------------
# epoch: 79  train_loss:0.001442365  validate_loss:0.001102169  best_val_loss:0.001129869
#
# Epoch 80-----------------------------------------------
# epoch: 80  train_loss:0.006670761  validate_loss:0.001494562  best_val_loss:0.001102169
#
# Epoch 81-----------------------------------------------
# epoch: 81  train_loss:0.002752832  validate_loss:0.001110156  best_val_loss:0.001102169
#
# Epoch 82-----------------------------------------------
# epoch: 82  train_loss:0.008441114  validate_loss:0.001164658  best_val_loss:0.001102169
#
# Epoch 83-----------------------------------------------
# epoch: 83  train_loss:0.005947684  validate_loss:0.001205091  best_val_loss:0.001102169
#
# Epoch 84-----------------------------------------------
# epoch: 84  train_loss:0.010570531  validate_loss:0.001117277  best_val_loss:0.001102169
#
# Epoch 85-----------------------------------------------
# epoch: 85  train_loss:0.004878599  validate_loss:0.001112738  best_val_loss:0.001102169
#
# Epoch 86-----------------------------------------------
# epoch: 86  train_loss:0.007365387  validate_loss:0.001120089  best_val_loss:0.001102169
#
# Epoch 87-----------------------------------------------
# epoch: 87  train_loss:0.006254947  validate_loss:0.001065058  best_val_loss:0.001102169
#
# Epoch 88-----------------------------------------------
# epoch: 88  train_loss:0.005508652  validate_loss:0.001065160  best_val_loss:0.001065058
#
# Epoch 89-----------------------------------------------
# epoch: 89  train_loss:0.010401095  validate_loss:0.001132298  best_val_loss:0.001065058
#
# Epoch 90-----------------------------------------------
# epoch: 90  train_loss:0.009410607  validate_loss:0.001084887  best_val_loss:0.001065058
#
# Epoch 91-----------------------------------------------
# epoch: 91  train_loss:0.006550867  validate_loss:0.001093110  best_val_loss:0.001065058
#
# Epoch 92-----------------------------------------------
# epoch: 92  train_loss:0.005156516  validate_loss:0.001100600  best_val_loss:0.001065058
#
# Epoch 93-----------------------------------------------
# epoch: 93  train_loss:0.009942465  validate_loss:0.001061148  best_val_loss:0.001065058
#
# Epoch 94-----------------------------------------------
# epoch: 94  train_loss:0.003763568  validate_loss:0.001058379  best_val_loss:0.001061148
#
# Epoch 95-----------------------------------------------
# epoch: 95  train_loss:0.003936199  validate_loss:0.001096443  best_val_loss:0.001058379
#
# Epoch 96-----------------------------------------------
# epoch: 96  train_loss:0.005810835  validate_loss:0.001176268  best_val_loss:0.001058379
#
# Epoch 97-----------------------------------------------
# epoch: 97  train_loss:0.005720729  validate_loss:0.001264725  best_val_loss:0.001058379
#
# Epoch 98-----------------------------------------------
# epoch: 98  train_loss:0.008263879  validate_loss:0.001142757  best_val_loss:0.001058379
#
# Epoch 99-----------------------------------------------
# epoch: 99  train_loss:0.004808598  validate_loss:0.001488079  best_val_loss:0.001058379

# %%
# start testing
snrdBvec, performance = test_model(model=model, criterion=criterion, args=args)
print('snrdBvec:', snrdBvec)
print('performance:', performance)
print("Done!-----------------------------------------------------------------\n")

np.save('snrdBvec.npy', snrdBvec)
np.save('performance_fixed.npy', performance)


# Create a figure and axis
fig, ax = plt.subplots()
# Plot data
ax.semilogy(snrdBvec, performance, label='MSE vs SNR', marker='o')
# Set labels and title
ax.set_xlabel('SNR (dB)')
ax.set_ylabel('MSE')
ax.set_title('MSE vs SNR')
# Display legend
ax.legend()
# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 # start testing
# ----> 2 snrdBvec, performance = test_model(model=model, criterion=criterion, args=args)
#       3 print('snrdBvec:', snrdBvec)
#       4 print('performance:', performance)
#
# NameError: name 'model' is not defined

# %%
data_snrdBvec = np.load('snrdBvec.npy')
data_performance = np.load('performance_fixed.npy')

print(data_snrdBvec)
print(data_performance)

angle_degree = np.sqrt(data_performance)*180/np.pi

 # Create a figure and axis
fig, ax = plt.subplots()
# Plot data
ax.semilogy(snrdBvec, angle_degree, label='angle degree vs SNR', marker='o')
# Set labels and title
ax.set_xlabel('SNR (dB)')
ax.set_ylabel('angular deviation (degree)')
ax.set_title('angle degree vs SNR')
# Display legend
ax.legend()
# Show the plot
plt.show()
# Out:
# [-10.  -5.   0.   5.  10.  15.  20.  25.]
# [0.01543242 0.00388493 0.00102872 0.0003969  0.00023863 0.00019313
#  0.00017843 0.00018254]

# %%
print(np.sqrt(1/(99.0+1.0)))
# Out:
# 0.1
